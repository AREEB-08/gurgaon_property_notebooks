# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
import category_encoders as ce
import joblib
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
import category_encoders as ce
from sklearn.model_selection import GridSearchCV, KFold, train_test_split

# %%
df = pd.read_csv('gurgaon_properties_post_feature_selection_v2.csv')

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat   sector 36   0.82      3.0       2.0       2    New Property
# 1          flat   sector 89   0.95      2.0       2.0       2    New Property
# 2          flat  sohna road   0.32      2.0       2.0       1    New Property
# 3          flat   sector 92   1.60      3.0       4.0      3+  Relatively New
# 4          flat  sector 102   0.48      2.0       2.0       1  Relatively New
#
#    built_up_area  servant room  store room  furnishing_type luxury_category  \
# 0          850.0           0.0         0.0              0.0             Low
# 1         1226.0           1.0         0.0              0.0             Low
# 2         1000.0           0.0         0.0              0.0             Low
# 3         1615.0           1.0         0.0              1.0            High
# 4          582.0           0.0         1.0              0.0            High
#
#   floor_category
# 0      Low Floor
# ...

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# 0.0    2349
# 1.0    1018
# 2.0     187
# Name: count, dtype: int64

# %%
# 0 -> unfurnished
# 1 -> semifurnished
# 2 -> furnished
df['furnishing_type'] = df['furnishing_type'].replace({0.0:'unfurnished',1.0:'semifurnished',2.0:'furnished'})

# %%
df.head()
# Out:
#   property_type      sector  price  bedRoom  bathroom balcony   agePossession  \
# 0          flat   sector 36   0.82      3.0       2.0       2    New Property
# 1          flat   sector 89   0.95      2.0       2.0       2    New Property
# 2          flat  sohna road   0.32      2.0       2.0       1    New Property
# 3          flat   sector 92   1.60      3.0       4.0      3+  Relatively New
# 4          flat  sector 102   0.48      2.0       2.0       1  Relatively New
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0          850.0           0.0         0.0     unfurnished             Low
# 1         1226.0           1.0         0.0     unfurnished             Low
# 2         1000.0           0.0         0.0     unfurnished             Low
# 3         1615.0           1.0         0.0   semifurnished            High
# 4          582.0           0.0         1.0     unfurnished            High
#
#   floor_category
# 0      Low Floor
# ...

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
# Applying the log1p transformation to the target variable
y_transformed = np.log1p(y)

# %% [markdown]
# ### Ordinal Encoding

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (0.7363096633436828, 0.03238005754429935)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.9463822160089356

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_output
# Out:
# [['linear_reg', 0.7363096633436828, 0.9463822160089356],
#  ['svr', 0.7642012011196353, 0.8472636473483922],
#  ['ridge', 0.7363125343993554, 0.9463387741853366],
#  ['LASSO', 0.05943378064493573, 1.528905986892753],
#  ['decision tree', 0.7755840738359898, 0.7384927833475707],
#  ['random forest', 0.8802350480635954, 0.5317710782857733],
#  ['extra trees', 0.8679746231327421, 0.5462333711565992],
#  ['gradient boosting', 0.8726850764679952, 0.5762396797503557],
#  ['adaboost', 0.7573001662225319, 0.8136165155886815],
#  ['mlp', 0.8110356584927226, 0.7156374903823675],
#  ['xgboost', 0.8894876835260124, 0.5040475141482346]]

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.889488  0.504048
# 5       random forest  0.880235  0.531771
# 6         extra trees  0.867975  0.546233
# 7   gradient boosting  0.872685  0.576240
# 9                 mlp  0.811036  0.715637
# 4       decision tree  0.775584  0.738493
# 8            adaboost  0.757300  0.813617
# 1                 svr  0.764201  0.847264
# 2               ridge  0.736313  0.946339
# 0          linear_reg  0.736310  0.946382
# 3               LASSO  0.059434  1.528906

# %% [markdown]
# ### OneHotEncoding

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first'),['sector','agePossession','furnishing_type'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# 0.8546082405684254

# %%
scores.std()
# Out:
# 0.016004959192136247

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
# ...

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.6497643322129935

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.895565  0.469543
# 10            xgboost  0.895850  0.493456
# 5       random forest  0.890946  0.496905
# 9                 mlp  0.875585  0.563860
# 7   gradient boosting  0.876522  0.568584
# 0          linear_reg  0.854608  0.649764
# 2               ridge  0.854636  0.652828
# 4       decision tree  0.804217  0.690840
# 8            adaboost  0.751657  0.824471
# 1                 svr  0.769741  0.834124
# 3               LASSO  0.059434  1.528906

# %% [markdown]
# ### OneHotEncoding With PCA

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['sector','agePossession'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=0.95)),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()

# %%
scores.std()

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('pca', PCA(n_components=0.95)),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])

# %% [markdown]
# ### Target Encoder

# %%
import category_encoders as ce

columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'regressor__n_estimators': [50, 100, 200, 300],
    'regressor__max_depth': [None, 10, 20, 30],
    'regressor__max_samples':[0.1, 0.25, 0.5, 1.0],
    'regressor__max_features': ['sqrt', 'log2', None] 
}

# %%
columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4)

# %%
search.fit(X, y_transformed)

# %%
final_pipe = search.best_estimator_

# %%
print("BEST PARAMTER FOR RANDOM FOREST REGRESSOR ")
search.best_params_

# %%
print(f"Best CV R² Score: {search.best_score_:.4f}")

# %%
final_pipe

# %% [markdown]
# ### Exporting the model

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['sector','agePossession'])
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(n_estimators=500))
])

# %% [markdown]
# # PIPELINE FOR RANDOM FOREST REGRESSOR

# %%
pipeline.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'built_up_area',
#                                                    'servant room',
#                                                    'store room']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['property_type', 'sector',
#                                                    'balcony', 'agePossession',
#                                                    'furnishing_type',
#                                                    'luxury_category',
#                                                    'floor_category']),
#                                                  ('cat1',
# ...

# %% [markdown]
# ## R2 , ACCURACY AND MAE OF RANDOM FOREST REGRESSOR for the best paprameters which we have calculated earlier

# %%
# Random Forest Regressor with Best Parameters
# ==========================================
rf_model = RandomForestRegressor(
    n_estimators=300,
    max_depth=20,
    max_features='sqrt',
    max_samples=1.0,
    random_state=42,
    n_jobs=-1
)


# Full Pipeline (Preprocessing + Model)
# ==========================================
pipeline_rf = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', rf_model)
])

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y_transformed, test_size=0.2, random_state=42)


# Model Training
pipeline_rf.fit(X_train, y_train)


# Model Evaluation
y_pred_log = pipeline_rf.predict(X_test)
y_pred = np.expm1(y_pred_log)
y_true = np.expm1(y_test)

r2 = r2_score(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)
accuracy = r2 * 100

print("\nModel Performance (Random Forest):")
print(f"R² Score: {r2:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Approx. Accuracy: {accuracy:.2f}%")

# %% [markdown]
# ## EXPORTING THE RANDOM FOREST REGRESSOR IN PICKLE FORM

# %%
import pickle

with open('RANDOM_FOREST_pipeline.pkl', 'wb') as file:
    pickle.dump(pipeline, file)

# %%
with open('df.pkl', 'wb') as file:
    pickle.dump(X, file)

# %%
X

# %% [markdown]
# ### Trying out the predictions

# %%
X.columns

# %%
X.iloc[0].values

# %%
data = [['house', 'sector 102', 4, 3, '3+', 'New Property', 2750, 0, 0, 'unfurnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
       'agePossession', 'built_up_area', 'servant room', 'store room',
       'furnishing_type', 'luxury_category', 'floor_category']

# Convert to DataFrame
one_df = pd.DataFrame(data, columns=columns)

one_df

# %%
np.expm1(pipeline.predict(one_df))

# %% [markdown]
# ### TESTING PREDICTION FROM THE SAVED MODEL OF RANDOM FOREST

# %%
with open('RANDOM_FOREST_pipeline.pkl', 'rb') as file:
    loaded_pipeline = pickle.load(file)

data = [['house', 'sector 102', 4, 3, '3+', 'New Property', 2750, 0, 0,
         'unfurnished', 'Low', 'Low Floor']]

columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
           'agePossession', 'built_up_area', 'servant room', 'store room',
           'furnishing_type', 'luxury_category', 'floor_category']

one_df = pd.DataFrame(data, columns=columns)
y_pred_log = loaded_pipeline.predict(one_df)

# If your model was trained on log1p-transformed target, use expm1 to revert it.
# Otherwise, remove this line.
y_pred = np.expm1(y_pred_log)

print("Predicted log price:", y_pred_log[0])
print("Predicted actual price:", y_pred[0])

# %%
X.dtypes

# %%
sorted(X['sector'].unique().tolist())

# %% [markdown]
# ## XG BOOST MODEL

# %%
y_transformed = np.log1p(y)  # log1p for better target distribution

columns_to_encode = ['property_type','sector', 'balcony', 'agePossession', 'furnishing_type', 'luxury_category', 'floor_category']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['agePossession']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ], 
    remainder='passthrough'
)
# Base Model (XGBoost)
xgb = XGBRegressor(
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1,
    tree_method='hist'  # fast histogram algorithm
)


# Pipeline (Preprocessor + Model)

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', xgb)
])


# Parameter Grid for Hyperparameter Tuning
#
param_grid = {
    'regressor__n_estimators': [100, 200, 300, 500],
    'regressor__max_depth': [3, 5, 7, 10],
    'regressor__learning_rate': [0.05, 0.1, 0.2],
    'regressor__subsample': [0.8, 1.0],
    'regressor__colsample_bytree': [0.7, 0.8, 1.0]
}

#  K-Fold and Grid Search
# ======================================
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=kfold,
    scoring='r2',
    n_jobs=-1,
    verbose=3
)
#Model Training with Grid Search
search.fit(X, y_transformed)

print("\n Best Parameters Found:")
print(search.best_params_)

print(f"Best CV R² Score: {search.best_score_:.4f}")


# Best Model Pipeline

best_pipeline = search.best_estimator_


# Final Evaluation on Test Set
# ======================================
X_train, X_test, y_train, y_test = train_test_split(X, y_transformed, test_size=0.2, random_state=42)

best_pipeline.fit(X_train, y_train)

y_pred_log = best_pipeline.predict(X_test)
y_pred = np.expm1(y_pred_log)
y_true = np.expm1(y_test)

r2 = r2_score(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

print("\n Final Model Performance:")
print(f"R² (original scale): {r2:.4f}")
print(f"MAE (original scale): {mae:.4f}")

# ======================================
# Save the Entire Pipeline (Model + Preprocessing)
# ======================================
joblib.dump(best_pipeline, "XGB_full_pipeline.pkl")
print()
print("Saved: 'XGB_full_pipeline.pkl' (includes preprocessing + model)")
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
#
#  Best Parameters Found:
# {'regressor__colsample_bytree': 0.7, 'regressor__learning_rate': 0.05, 'regressor__max_depth': 7, 'regressor__n_estimators': 500, 'regressor__subsample': 0.8}
# Best CV R² Score: 0.9092
#
#  Final Model Performance:
# R² (original scale): 0.8540
# MAE (original scale): 0.4526
#
# Saved: 'XGB_full_pipeline.pkl' (includes preprocessing + model)

# %% [markdown]
# #### XG BOOST PREDICTION FROM SAVED MODEL

# %%
data = [['house', 'sector 102', 4, 3, '3+', 'New Property', 2750, 0, 0, 'unfurnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
           'agePossession', 'built_up_area', 'servant room', 'store room',
           'furnishing_type', 'luxury_category', 'floor_category']

sample_df = pd.DataFrame(data, columns=columns)

predicted_price = np.expm1(best_pipeline.predict(sample_df))
print(f"\n Predicted Price: {predicted_price[0]:,.2f}")

# %%
xgb = joblib.load('XGB_full_pipeline.pkl')
np.expm1(xgb.predict(one_df))[0]

# %% [markdown]
# # PIPELINE FOR XGBOOST REGRESSOR

# %%
best_pipeline

# %% [markdown]
# # EXTRA TREE REGRESSOR

# %%
# Defining the columns that require encoding.
columns_to_encode = [
    'property_type', 'sector', 'balcony', 'agePossession',
    'furnishing_type', 'luxury_category', 'floor_category'
]

# Creating a ColumnTransformer to handle both numerical and categorical preprocessing.
preprocessor = ColumnTransformer(
    transformers=[
        # Standardize numerical features
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'built_up_area', 'servant room', 'store room']),
        # Encode ordinal categorical features
        ('cat', OrdinalEncoder(), columns_to_encode),
        # One-hot encode 'agePossession' for better feature representation
        ('cat1', OneHotEncoder(drop='first', sparse_output=False), ['agePossession']),
        # Apply target encoding to 'sector' to capture mean target relationships
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ],
    remainder='passthrough'
)

# ======================================
# Model Definition
# ======================================
# Initializing the Extra Trees Regressor with parallel processing.
extra_trees = ExtraTreesRegressor(
    random_state=42,
    n_jobs=-1
)

# ======================================
# Pipeline Setup
# ======================================
# Building a pipeline that combines preprocessing and model training.
pipeline_et = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', extra_trees)
])
# Hyperparameter Grid
# Defining the parameter grid for tuning Extra Trees.
param_grid_et = {
    'regressor__n_estimators': [100, 200, 300, 500],
    'regressor__max_depth': [None, 10, 20, 30],
    'regressor__min_samples_split': [2, 5, 10],
    'regressor__min_samples_leaf': [1, 2, 4],
    'regressor__max_features': ['sqrt', 'log2', None]
}
# Cross-Validation and Grid Search
# ======================================
# Using K-Fold cross-validation for model evaluation.
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Performing grid search to find the best hyperparameters.
search_et = GridSearchCV(
    estimator=pipeline_et,
    param_grid=param_grid_et,
    cv=kfold,
    scoring='r2',
    n_jobs=-1,
    verbose=3
)

# ======================================
# Model Training
# ======================================
# Fitting the model using grid search.
search_et.fit(X, y_transformed)

print("\nBest Parameters (Extra Trees):")
print(search_et.best_params_)
print(f"Best Cross-Validation R² Score (log scale): {search_et.best_score_:.4f}")


# Best Model Extraction
# ======================================
# Retrieving the best model pipeline from grid search results.
best_pipeline_et = search_et.best_estimator_

# ======================================
# Final Evaluation on Test Set
# ======================================
# Splitting the data for evaluation.
X_train, X_test, y_train, y_test = train_test_split(
    X, y_transformed, test_size=0.2, random_state=42
)

# Training the best model on the training set.
best_pipeline_et.fit(X_train, y_train)

# Predicting on the test set.
y_pred_log = best_pipeline_et.predict(X_test)

# Reversing the log transformation to return to the original scale.
y_pred = np.expm1(y_pred_log)
y_true = np.expm1(y_test)

# Evaluating model performance.
r2 = r2_score(y_true, y_pred)
mae = mean_absolute_error(y_true, y_pred)

print("\nFinal Model Performance (Extra Trees):")
print(f"R² (original scale): {r2:.4f}")
print(f"MAE (original scale): {mae:.4f}")

# ======================================
# Model Saving
# ======================================
# Saving the trained pipeline, which includes preprocessing and the model itself.
joblib.dump(best_pipeline_et, "EXTRA_TREES_full_pipeline.pkl")

print("\nModel saved as 'EXTRA_TREES_full_pipeline.pkl' (includes preprocessing and model).")
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
#
# Best Parameters (Extra Trees):
# {'regressor__max_depth': 20, 'regressor__max_features': None, 'regressor__min_samples_leaf': 1, 'regressor__min_samples_split': 2, 'regressor__n_estimators': 100}
# Best Cross-Validation R² Score (log scale): 0.9008
#
# Final Model Performance (Extra Trees):
# R² (original scale): 0.8502
# MAE (original scale): 0.4595

# %%
# ======================================
# 🔮 Example Prediction
# ======================================
data = [['house', 'sector 102', 4, 3, '3+', 'New Property', 2750, 0, 0, 'unfurnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
           'agePossession', 'built_up_area', 'servant room', 'store room',
           'furnishing_type', 'luxury_category', 'floor_category']

sample_df = pd.DataFrame(data, columns=columns)

predicted_price = np.expm1(best_pipeline_et.predict(sample_df))
print(f"\n Predicted Price: {predicted_price[0]:,.2f}")

# %%
# PREDICTING FOR A NEW ROW 
ext = joblib.load('EXTRA_TREES_full_pipeline.pkl')
np.expm1(ext.predict(one_df))[0]
# Out:
# 2.584173176177114

# %% [markdown]
# # PIPELINE FOR EXTRA TREE REGRESSOR

# %%
best_pipeline_et

# %%
data = [['house', 'sector 49', 3, 3, '3+', 'New Property', 1750, 0, 0, 'unfurnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
       'agePossession', 'built_up_area', 'servant room', 'store room',
       'furnishing_type', 'luxury_category', 'floor_category']

# Convert to DataFrame
one_df_2 = pd.DataFrame(data, columns=columns)

one_df_2
# Out:
#   property_type     sector  bedRoom  bathroom balcony agePossession  \
# 0         house  sector 49        3         3      3+  New Property
#
#    built_up_area  servant room  store room furnishing_type luxury_category  \
# 0           1750             0           0     unfurnished             Low
#
#   floor_category
# 0      Low Floor

# %%
# PREDICTING FOR A NEW ROW FROM THE EXTRA TREE 
ext = joblib.load('EXTRA_TREES_full_pipeline.pkl')
result=np.expm1(ext.predict(one_df_2))[0]

print('result from the extra tress -> ',result)
# Out:
# result from the extra tress ->  2.544298867750927

# %%
# PREDICTION FROM THE XGBOOST MODEL

xgb = joblib.load('XGB_full_pipeline.pkl')
np.expm1(xgb.predict(one_df_2))[0]
# Out:
# 2.7656572

# %%
# PREDICTION FROM THE RANDOM FOREST

with open('RANDOM_FOREST_pipeline.pkl', 'rb') as file:
    loaded_pipeline = pickle.load(file)

y_pred_log = loaded_pipeline.predict(one_df_2)

y_pred = np.expm1(y_pred_log)

print("Predicted actual price:", y_pred[0])
# Out:
# Predicted actual price: 2.8040142949432036

# %%
# PREDICTING FOR A NEW ROW FROM THE EXTRA TREE 
ext = joblib.load('EXTRA_TREES_full_pipeline.pkl')
result1=np.expm1(ext.predict(one_df_2))[0]

# print('result from the extra tress -> ',result)
# PREDICTION FROM THE XGBOOST MODEL

xgb = joblib.load('XGB_full_pipeline.pkl')
result2=np.expm1(xgb.predict(one_df_2))[0]
# PREDICTION FROM THE RANDOM FOREST

with open('RANDOM_FOREST_pipeline.pkl', 'rb') as file:
    loaded_pipeline = pickle.load(file)

y_pred_log = loaded_pipeline.predict(one_df_2)

y_pred = np.expm1(y_pred_log)

result3= y_pred[0]
print((result1+result2+result3)/3)
# Out:
# 1.7755908922772303

# %%
data = [['house', 'sector 102', 3, 3, '3+', 'New Property', 2750, 0, 0, 'unfurnished', 'Low', 'Low Floor']]
columns = ['property_type', 'sector', 'bedRoom', 'bathroom', 'balcony',
       'agePossession', 'built_up_area', 'servant room', 'store room',
       'furnishing_type', 'luxury_category', 'floor_category']

# Convert to DataFrame
one_df_2 = pd.DataFrame(data, columns=columns)

one_df_2

# PREDICTING FOR A NEW ROW FROM THE EXTRA TREE 
ext = joblib.load('EXTRA_TREES_full_pipeline.pkl')
result1=np.expm1(ext.predict(one_df_2))[0]

print('result from the extra tress -> ',result1)


# PREDICTION FROM THE XGBOOST MODEL

xgb = joblib.load('XGB_full_pipeline.pkl')
result2=np.expm1(xgb.predict(one_df_2))[0]
print('result from the xg boost-> ',result2)
# PREDICTION FROM THE RANDOM FOREST

with open('RANDOM_FOREST_pipeline.pkl', 'rb') as file:
    loaded_pipeline = pickle.load(file)

y_pred_log = loaded_pipeline.predict(one_df_2)

y_pred = np.expm1(y_pred_log)

result3= y_pred[0]
print('result from the random forest -> ',result3)
# Out:
# result from the extra tress ->  2.5121386388810154
# result from the xg boost->  2.7219052
# result from the random forest ->  2.901138368390091

# %%
# Out:
# Model Performance (Random Forest):
# R² Score: 0.8597
# Mean Absolute Error (MAE): 0.47
# Approx. Accuracy: 85.97%
